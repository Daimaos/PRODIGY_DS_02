# %% [markdown]
# # 📊 Prodigy InfoTech Data Science Internship
#
# ## 📝 Task-02: Data Cleaning & Exploratory Data Analysis (EDA)
#
# **Intern:** Hashir Muhammed
# **Track:** Data Science
# **Task Code:** PRODIGY_DS_02
#
# ---
#
# ## 🎯 Task Objective:
#
# Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice — exploring relationships between variables, identifying patterns, and trends in the data.
#
# **Dataset Source:** [Kaggle Titanic Dataset](https://www.kaggle.com/c/titanic/data)
#
# ---
#
# ## 🛠️ Tools Used:
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn

# %% [markdown]
# ## 📥 Step 1: Import Required Libraries

# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set(style="whitegrid")

# %% [markdown]
# ## 📑 Step 2: Load the Titanic Dataset

# %%
# Load dataset (assumes CSV file is available locally as 'titanic.csv')
df = pd.read_csv('titanic.csv')

# Display first 5 records
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 📝 Step 3: Explore Dataset Structure and Info

# %%
# Dataset structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Check summary statistics
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Check for missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 🧹 Step 4: Data Cleaning

# %%
# Fill missing 'Age' values with median age
df['Age'].fillna(df['Age'].median(), inplace=True)

# Fill missing 'Embarked' values with mode
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# Drop 'Cabin' due to high missing data
df.drop(columns='Cabin', inplace=True)

# Confirm no missing values remain
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## 📊 Step 5: Exploratory Data Analysis (EDA)

# %%
# Bar Plot: Survival Count
sns.countplot(x='Survived', data=df, palette='Set2')
plt.title('Survival Count')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %%
# Bar Plot: Survival by Gender
sns.countplot(x='Sex', hue='Survived', data=df, palette='Set1')
plt.title('Survival by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Histogram: Age Distribution
plt.figure(figsize=(8,5))
plt.hist(df['Age'], bins=30, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot: Age by Pclass
sns.boxplot(x='Pclass', y='Age', data=df, palette='Pastel1')
plt.title('Age Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.show()

# %%
# Heatmap: Correlation Matrix
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Heatmap: Correlation Matrix
#       2 plt.figure(figsize=(10,6))
# ----> 3 sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')
#       4 plt.title('Correlation Heatmap')
#       5 plt.show()
#
# File c:\Users\Hashi\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Hashi\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# ...

# %%
# Heatmap: Correlation Matrix (only numeric columns)
plt.figure(figsize=(10,6))

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['number'])

# Generate heatmap
sns.heatmap(numeric_df.corr(), annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## 📊 Additional EDA Visualizations

# %%
# Countplot: Gender Distribution
plt.figure(figsize=(8,5))
sns.countplot(x='Sex', data=df, palette='pastel')
plt.title('Passenger Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Countplot: Survival by Gender
plt.figure(figsize=(8,5))
sns.countplot(x='Sex', hue='Survived', data=df, palette='coolwarm')
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(labels=['Did Not Survive', 'Survived'])
plt.show()

# %%
# Histogram: Age Distribution
plt.figure(figsize=(10,6))
sns.histplot(df['Age'].dropna(), bins=30, kde=True, color='skyblue')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.show()

# %%
# Countplot: Survival by Pclass
plt.figure(figsize=(8,5))
sns.countplot(x='Pclass', hue='Survived', data=df, palette='Set2')
plt.title('Survival Count by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(labels=['Did Not Survive', 'Survived'])
plt.show()

# %%
# Violinplot: Fare vs Pclass
plt.figure(figsize=(10,6))
sns.violinplot(x='Pclass', y='Fare', data=df, palette='muted')
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %%
# Pie Chart: Survival Rate
plt.figure(figsize=(6,6))
df['Survived'].value_counts().plot.pie(autopct='%1.1f%%', colors=['#ff9999','#66b3ff'], labels=['Did Not Survive','Survived'])
plt.title('Overall Survival Rate')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## 📌 Overall Conclusion:
#
# - Conducted comprehensive exploratory data analysis (EDA) on the Titanic dataset to understand passenger demographics and survival patterns.
# - Identified key relationships between variables such as **Gender**, **Passenger Class (Pclass)**, **Age**, and **Fare** with survival outcomes.
# - Visualizations revealed that:
#   - Females had a significantly higher survival rate compared to males.
#   - Passengers in higher classes (1st class) had better survival chances than those in lower classes.
#   - Age distribution showed most passengers were young adults, and survival varied across age groups.
#   - Fare prices varied widely across classes, correlating with survival likelihood.
# - The correlation heatmap helped identify numerical feature relationships, guiding further analysis and feature selection.
# - These insights provide a strong foundation for building predictive models and further data-driven decision-making.
#
# ---
